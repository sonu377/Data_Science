# %% [markdown]
# <a href="https://colab.research.google.com/github/ArjunJadhav-data/Data_Science/blob/main/Heavychocolate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data=pd.read_excel("/content/HeavenlyChocolates.xlsx")
data
# Out:
#     Customer  Day  Browser  Time (min)  Pages Viewed  Amount Spent ($)
# 0          1  Mon   Chrome        12.0             4             54.52
# 1          2  Wed    Other        19.5             6             94.90
# 2          3  Mon   Chrome         8.5             4             26.68
# 3          4  Tue  Firefox        11.4             2             44.73
# 4          5  Wed   Chrome        11.3             4             66.27
# 5          6  Sat  Firefox        10.5             6             67.80
# 6          7  Sun   Chrome        11.4             2             36.04
# 7          8  Fri  Firefox         4.3             6             55.96
# 8          9  Wed  Firefox        12.7             3             70.94
# 9         10  Tue   Chrome        24.7             7             68.73
# 10        11  Sat    Other        13.3             6             54.04
# 11        12  Sun  Firefox        14.3             5             48.05
# ...

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_excel("/content/HeavenlyChocolates.xlsx")
data
# Out:
#     Customer  Day  Browser  Time (min)  Pages Viewed  Amount Spent ($)
# 0          1  Mon   Chrome        12.0             4             54.52
# 1          2  Wed    Other        19.5             6             94.90
# 2          3  Mon   Chrome         8.5             4             26.68
# 3          4  Tue  Firefox        11.4             2             44.73
# 4          5  Wed   Chrome        11.3             4             66.27
# 5          6  Sat  Firefox        10.5             6             67.80
# 6          7  Sun   Chrome        11.4             2             36.04
# 7          8  Fri  Firefox         4.3             6             55.96
# 8          9  Wed  Firefox        12.7             3             70.94
# 9         10  Tue   Chrome        24.7             7             68.73
# 10        11  Sat    Other        13.3             6             54.04
# 11        12  Sun  Firefox        14.3             5             48.05
# ...

# %%
X=data[['Time (min)']]

# %%
y=data['Amount Spent ($)']

# %%
model =LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[12]])
# Out:
# array([65.62192288])

# %%
data.describe()
# Out:
#        Customer  Time (min)  Pages Viewed  Amount Spent ($)
# count  50.00000   50.000000     50.000000         50.000000
# mean   25.50000   12.810000      4.820000         68.128200
# std    14.57738    6.063314      2.037305         32.343758
# min     1.00000    4.300000      2.000000         17.840000
# 25%    13.25000    8.650000      3.250000         45.560000
# 50%    25.50000   11.400000      4.500000         62.150000
# 75%    37.75000   14.900000      6.000000         82.735000
# max    50.00000   32.900000     10.000000        158.510000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data=data,x='Time (min)',y='Amount Spent ($)')
# Out:
# <Axes: xlabel='Time (min)', ylabel='Amount Spent ($)'>

# %%
sns.histo(data,x=)

# %%
sns.scatterplot(data=data,x='Time (min)',y='Amount Spent ($)')
# Out:
# <Axes: xlabel='Time (min)', ylabel='Amount Spent ($)'>

# %%
ab
# Out:
# <Axes: xlabel='Time (min)', ylabel='Amount Spent ($)'>

# %%
mean_amount_spent
# Out:
# np.float64(68.12819999999999)

# %%
sns.barplot(data=data,y='Time (min)',x='Amount Spent ($)')
# Out:
# <Axes: xlabel='Amount Spent ($)', ylabel='Time (min)'>
